# %% [markdown]
# # Call NYC OpenData API

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
from sodapy import Socrata
import mobility_config

# %%
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
client = Socrata("data.cityofnewyork.us", '7YJroGSBVCt6gzuLz6whih0yc')

# Example authenticated client (needed for non-public datasets):
client = Socrata('data.cityofnewyork.us',
                  mobility_config.app_token,
                  username=mobility_config.app_user,
                  password=mobility_config.app_pw)

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
trip_diary = client.get("kcey-vehy", limit=8000)
main_survey = client.get("jpcp-ic7c", limit=4000)
# Convert to pandas DataFrame
trip_diary_df = pd.DataFrame.from_records(trip_diary)
main_survey_df = pd.DataFrame.from_records(main_survey)

# %%
trip_diary_df.head()
# Out:
#       job   trip_id  uniqueid      qday  qday1typical qborough_home  \
# 0  Online   3101674    101674    Sunday            NA        Queens
# 1   Phone  11202717  10202717  Saturday  Very typical        Queens
# 2   Phone  12202717  10202717  Saturday  Very typical        Queens
# 3   Phone  51200330  50200330  Thursday  Very typical        Queens
# 4   Phone  52200330  50200330  Thursday  Very typical        Queens
#
#   qsurveyzone_home qtripdaytime          qday1tripstartcode  \
# 0    Middle Queens         NOON                        Home
# 1    Middle Queens           AM                        Work
# 2    Middle Queens         NOON                        Home
# 3    Middle Queens           AM                        Home
# 4    Middle Queens           AM  Park/Recreational area/Gym
#
#              qday1tripstartam qday1tripstartnoon qday1tripstartpm  \
# 0                          NA               Home               NA
# 1                        Work                 NA               NA
# 2                          NA               Home               NA
# 3                        Home                 NA               NA
# 4  Park/Recreational area/Gym                 NA               NA
#
#   qday1trip_outsidenyc_start qborough_start qntacode_start surveyzone_start  \
# 0                         NA         Queens           QN43     Outer Queens
# 1                         NA         Queens            NaN               NA
# 2                         NA             NA            NaN               NA
# 3                         NA         Queens            NaN    Middle Queens
# 4                         NA         Queens            NaN    Middle Queens
#
#                  qday1tripend qday1trip_outsidenyc_end qborough_end  \
# 0                        Home                       NA       Queens
# 1                        Home                       NA           NA
# 2  Park/Recreational area/Gym                       NA       Queens
# 3  Park/Recreational area/Gym                       NA       Queens
# 4                        Home                       NA       Queens
#
#   qntacode_end surveyzone_end            qday1tripendcode qday1triptransitto1  \
# 0         QN76   Outer Queens                        Home                  NA
# 1          NaN             NA                        Home                  NA
# 2          NaN             NA  Park/Recreational area/Gym                  NA
# 3          NaN  Middle Queens  Park/Recreational area/Gym                  NA
# 4          NaN  Middle Queens                        Home                  NA
#
#   qday1triptransitto2 qday1triptransitto3 qday1triptransitto4  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#   qday1triptransitto5 qday1triptransitto6 qday1triptransitto7  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#   qday1triptransitfrom1 qday1triptransitfrom2 qday1triptransitfrom3  \
# 0                    NA                    NA                    NA
# 1                    NA                    NA                    NA
# 2                    NA                    NA                    NA
# 3                    NA                    NA                    NA
# 4                    NA                    NA                    NA
#
#   qday1triptransitfrom4 qday1triptransitfrom5 qday1triptransitfrom6  \
# 0                    NA                    NA                    NA
# 1                    NA                    NA                    NA
# 2                    NA                    NA                    NA
# 3                    NA                    NA                    NA
# 4                    NA                    NA                    NA
#
#   qday1triptransitfrom7 qday1triptravelcode01 qday1triptravelcode02  \
# 0                    NA                    No                    No
# 1                    NA                    No                    No
# 2                    NA                    No                    No
# 3                    NA                    No                    No
# 4                    NA                    No                    No
#
#   qday1triptravelcode03 qday1triptravelcode04 qday1triptravelcode05  \
# 0                    No                    No                    No
# 1                    No                    No                    No
# 2                    No                    No                    No
# 3                    No                    No                    No
# 4                    No                    No                    No
#
#   qday1triptravelcode06 qday1triptravelcode07 qday1triptravelcode08  \
# 0                    No                    No                    No
# 1                    No                    No                    No
# 2                    No                    No                    No
# 3                    No                    No                    No
# 4                    No                    No                    No
#
#   qday1triptravelcode09 qday1triptravelcode10 qday1triptravelcode11  \
# 0                    No                    No                    No
# 1                    No                    No                    No
# 2                    No                    No                    No
# 3                    No                    No                    No
# 4                    No                    No                    No
#
#   qday1triptravelcode12 qday1triptravelcode13 qday1triptravelcode14  \
# 0                    No                    No                    No
# 1                    No                    No                    No
# 2                    No                    No                    No
# 3                    No                    No                    No
# 4                    No                    No                    No
#
#   qday1triptravelcode15 qday1triptravelcode16 qday1triptravelcode17  \
# 0                    No                    No                    No
# 1                    No                    No                    No
# 2                    No                    No                    No
# 3                    No                    No                    No
# 4                    No                    No                    No
#
#   qday1triptravelcode18 qday1triptravelcode19 qday1triptravelcode20  \
# 0                    No                    No                    No
# 1                    No                    No                    No
# 2                    No                    No                    No
# 3                    No                    No                    No
# 4                    No                    No                    No
#
#   qday1triptravelcode21 qday1triptravelcode22 qday1triptravelcode23  \
# 0                    No                   Yes                    No
# 1                   Yes                    No                    No
# 2                   Yes                    No                    No
# 3                   Yes                    No                    No
# 4                   Yes                    No                    No
#
#   qday1triptravelcode24 qday1triptravelcode25 qday1triptravelcode26  \
# 0                    No                    No                    No
# 1                    No                    No                    No
# 2                    No                    No                    No
# 3                    No                    No                    No
# 4                    No                    No                    No
#
#   qday1triptravelcode27      qday1trippurpose qday1triplength  \
# 0                    No                School              11
# 1                    No  Commute to/from work              27
# 2                    No     Social/recreation              18
# 3                    No     Social/recreation              15
# 4                    No     Social/recreation              15
#
#   qday1triplength_flt qday1triplength_cat qday1trippark qday1tripparkpay  \
# 0                  11            11 to 15            NA               NA
# 1                  27            26 to 30            NA               NA
# 2                  18            16 to 20            NA               NA
# 3                  15            11 to 15            NA               NA
# 4                  15            11 to 15            NA               NA
#
#   qday1tripparkpay_amount         qday1tripbikestore number_of_trips_taken  \
# 0                      NA  In your home or apartment               3 trips
# 1                      NA  In your home or apartment               3 trips
# 2                      NA   In a dedicated bike room               3 trips
# 3                      NA    In a parking garage/lot               4 trips
# 4                      NA    In a parking garage/lot               4 trips
#
#   qgender            qincome qdisability1 qdisability2 qdisability3  \
# 0    Male  $50,000 - $74,999           No           No           No
# 1    Male  $50,000 - $74,999           No           No           No
# 2    Male  $50,000 - $74,999           No           No           No
# 3    Male  $50,000 - $74,999           No           No           No
# 4    Male  $50,000 - $74,999           No           No           No
#
#   qdisability4 qdisability5 qdisability6 qdisability7 qdisability8  \
# 0          Yes           No           No           No           No
# 1           No           No           No          Yes           No
# 2           No           No           No          Yes           No
# 3           No           No           No          Yes           No
# 4           No           No           No          Yes           No
#
#   qdisability9 qage qagecode                                        qrace  \
# 0           No   28    25-34                              White/Caucasian
# 1           No   28    25-34  Black/ African American/ Caribbean American
# 2           No   28    25-34  Black/ African American/ Caribbean American
# 3           No   62    55-64                              White/Caucasian
# 4           No   62    55-64                              White/Caucasian
#
#              qracecode                                       qhispanic  \
# 0  White, Non-Hispanic  No, not of Hispanic, Latino, or Spanish origin
# 1  Black, Non-Hispanic  No, not of Hispanic, Latino, or Spanish origin
# 2  Black, Non-Hispanic  No, not of Hispanic, Latino, or Spanish origin
# 3  White, Non-Hispanic  No, not of Hispanic, Latino, or Spanish origin
# 4  White, Non-Hispanic  No, not of Hispanic, Latino, or Spanish origin
#
#                                        qeducation qlicense  \
# 0  High school graduate or equivalent (i.e., GED)      Yes
# 1            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 2            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 3  High school graduate or equivalent (i.e., GED)      Yes
# 4  High school graduate or equivalent (i.e., GED)      Yes
#
#                         qcaraccess  \
# 0    I do not have access to a car
# 1  I personally own or lease a car
# 2  I personally own or lease a car
# 3  I personally own or lease a car
# 4  I personally own or lease a car
#
#                                     qcarchange qwelfare1 qwelfare2 qwelfare3  \
# 0  Reduced the number of cars it has access to        No       Yes        No
# 1                   The number has not changed        No        No       Yes
# 2                   The number has not changed        No        No       Yes
# 3                   The number has not changed        No        No       Yes
# 4                   The number has not changed        No        No       Yes
#
#   qwelfare4 qwelfare5 qsmartphone qshare1 qshare2 qshare3 qshare4 qshare5  \
# 0        No        No         Yes     Yes      No      No      No      No
# 1        No        No         Yes      No      No      No      No      No
# 2        No        No         Yes      No      No      No      No      No
# 3        No        No          No      No      No      No      No      No
# 4        No        No          No      No      No      No      No      No
#
#   qshare6 qshare7 qshare8 qtemphigh qtemplow qprecipitation qsunrise qsunset  \
# 0      No      No      No        79       58              0     5.33   20.12
# 1     Yes      No      No        66       51           0.25     5.26   20.22
# 2     Yes      No      No        66       51           0.25     5.26   20.22
# 3     Yes      No      No        73       57              0     5.43   20.02
# 4     Yes      No      No        73       57              0     5.43   20.02
#
#   qcitibike qday1triptravelcode_sp qmodegrouping qsustainablemode  \
# 0        NA              Citi Bike          Bike              Yes
# 1        No       Personal bicycle          Bike              Yes
# 2        No       Personal bicycle          Bike              Yes
# 3        No       Personal bicycle          Bike              Yes
# 4        No       Personal bicycle          Bike              Yes
#
#          allwt        qpurposerecode ntacode_home
# 0  2.269122796                School          NaN
# 1  0.868686684  Commute to/from work          NaN
# 2  0.868686684     Social/recreation          NaN
# 3   2.43311884     Social/recreation         QN60
# 4   2.43311884     Social/recreation         QN60

# %%
main_survey_df.head()
# Out:
#       job datacollection_starttime uniqueid    qday qntacode qgender qage  \
# 0  Online              13746130937   100938  Friday     QN28  Female   38
# 1  Online              13749321989   105388  Sunday     QN54    Male   55
# 2  Online              13749324591   105415  Sunday     MN36    Male   65
# 3  Online              13745513760   100402  Friday     BX06    Male   68
# 4  Online              13745174106   100222  Monday     MN36    Male   50
#
#       qagecode            qrace  \
# 0        35-44  White/Caucasian
# 1        55-64  White/Caucasian
# 2  65 or older  White/Caucasian
# 3  65 or older  White/Caucasian
# 4        45-54  White/Caucasian
#
#                                         qhispanic            qracecode  \
# 0  No, not of Hispanic, Latino, or Spanish origin  White, Non-Hispanic
# 1  No, not of Hispanic, Latino, or Spanish origin  White, Non-Hispanic
# 2  No, not of Hispanic, Latino, or Spanish origin  White, Non-Hispanic
# 3  No, not of Hispanic, Latino, or Spanish origin  White, Non-Hispanic
# 4  No, not of Hispanic, Latino, or Spanish origin  White, Non-Hispanic
#
#                                           qeducation              qincome  \
# 0  Graduate degree (i.e., Master's, Professional,...    $150,000-$199,999
# 1               Bachelor's degree (i.e., BA, BS, AB)  $100,000 - $149,999
# 2               Bachelor's degree (i.e., BA, BS, AB)    $25,000 - $34,999
# 3  Some college but degree not received or in pro...    $15,000 - $24,999
# 4  Graduate degree (i.e., Master's, Professional,...   $200,000 and above
#
#           qsurveyzone qziphome   qborough qlicense  \
# 0        Inner Queens    11372     Queens      Yes
# 1      Inner Brooklyn    11201   Brooklyn      Yes
# 2  Northern Manhattan    10039  Manhattan       No
# 3      Inner Brooklyn    11205   Brooklyn      Yes
# 4      Outer Brooklyn    11235   Brooklyn      Yes
#
#                                           qcaraccess qcarmanynum  \
# 0  I do not personally own or lease a car, but I ...           2
# 1                      I do not have access to a car          NA
# 2                      I do not have access to a car          NA
# 3                      I do not have access to a car          NA
# 4                      I do not have access to a car          NA
#
#   gcartype1_qcartype1_ma gcartype1_qcartype2_ma gcartype1_qcartype3_ma  \
# 0               Gasoline               Gasoline                     NA
# 1                     NA                     NA                     NA
# 2                     NA                     NA                     NA
# 3                     NA                     NA                     NA
# 4                     NA                     NA                     NA
#
#   gcartype1_qcartype4_ma qcarhybrid1 qcarhybrid2 qcarhybrid3 qcarhybrid4  \
# 0                     NA          NA          NA          NA          NA
# 1                     NA          NA          NA          NA          NA
# 2                     NA          NA          NA          NA          NA
# 3                     NA          NA          NA          NA          NA
# 4                     NA          NA          NA          NA          NA
#
#   qcarhybrid5 qcarhybrid6                  qcarchange qcarreducea1  \
# 0          NA          NA  The number has not changed           NA
# 1          NA          NA  The number has not changed           NA
# 2          NA          NA  The number has not changed           NA
# 3          NA          NA  The number has not changed           NA
# 4          NA          NA  The number has not changed           NA
#
#   qcarreducea2 qcarreducea3 qcarreducea4 qcarreducea5 qcarreducea6  \
# 0           NA           NA           NA           NA           NA
# 1           NA           NA           NA           NA           NA
# 2           NA           NA           NA           NA           NA
# 3           NA           NA           NA           NA           NA
# 4           NA           NA           NA           NA           NA
#
#   qcarreducea7 qcarreducea8 qcarreducea9 qcarincreasea1 qcarincreasea2  \
# 0           NA           NA           NA             NA             NA
# 1           NA           NA           NA             NA             NA
# 2           NA           NA           NA             NA             NA
# 3           NA           NA           NA             NA             NA
# 4           NA           NA           NA             NA             NA
#
#   qcarincreasea3 qcarincreasea4 qcarincreasea5 qcarincreasea6 qcarincreasea7  \
# 0             NA             NA             NA             NA             NA
# 1             NA             NA             NA             NA             NA
# 2             NA             NA             NA             NA             NA
# 3             NA             NA             NA             NA             NA
# 4             NA             NA             NA             NA             NA
#
#   qcarincreasea8 qcarincreasea9 qelectricconsider qnoelectric1 qnoelectric2  \
# 0             NA             NA                NA           NA           NA
# 1             NA             NA                NA           NA           NA
# 2             NA             NA                NA           NA           NA
# 3             NA             NA                NA           NA           NA
# 4             NA             NA                NA           NA           NA
#
#   qnoelectric3 qnoelectric4 qnoelectric5 qnoelectric6 qnoelectric7  \
# 0           NA           NA           NA           NA           NA
# 1           NA           NA           NA           NA           NA
# 2           NA           NA           NA           NA           NA
# 3           NA           NA           NA           NA           NA
# 4           NA           NA           NA           NA           NA
#
#   qnoelectric8                      gcarpark1_qcarpark1_ma  \
# 0           NA  In a single family home garage or driveway
# 1           NA                                          NA
# 2           NA                                          NA
# 3           NA                                          NA
# 4           NA                                          NA
#
#                        gcarpark1_qcarpark2_ma gcarpark1_qcarpark3_ma  \
# 0  In a single family home garage or driveway                     NA
# 1                                          NA                     NA
# 2                                          NA                     NA
# 3                                          NA                     NA
# 4                                          NA                     NA
#
#   gcarpark1_qcarpark4_ma qpaytopark qpaytopark_amount qshare1 qshare2 qshare3  \
# 0                     NA         NA                NA      No      No      No
# 1                     NA         NA                NA     Yes      No      No
# 2                     NA         NA                NA      No      No      No
# 3                     NA         NA                NA      No      No      No
# 4                     NA         NA                NA      No      No      No
#
#   qshare4 qshare5 qshare6 qshare7 qshare8 qsmartphone          qtripplanapp  \
# 0      No      No     Yes      No      No         Yes                 Daily
# 1      No      No      No      No      No         Yes           Once a week
# 2      No      No     Yes      No      No         Yes   A few times a month
# 3      No      No     Yes      No      No         Yes    A few times a year
# 4      No      No     Yes      No      No         Yes  Several times a week
#
#   qridehail1 qridehail2 qridehail3 qridehail4 qridehail5 qridehail6  \
# 0         NA         NA         NA         NA         NA         NA
# 1         No         No         No         No         No        Yes
# 2         No         No         No         No         No        Yes
# 3         No         No         No         No         No        Yes
# 4         NA         NA         NA         NA         NA         NA
#
#   qridehail7 qridehail8 qridehail_freq qridehailpurpose qbikeown qbikemany  \
# 0         NA         NA             NA               NA      Yes         2
# 1         No         No             NA               NA      Yes         2
# 2         No         No             NA               NA       No        NA
# 3         No         No             NA               NA       No        NA
# 4         NA         NA             NA               NA      Yes         2
#
#   qbiketype1 qbiketype2 qbiketype3 qbiketype4 qbiketype5 qbikestore1  \
# 0        Yes         No         No         No         No          No
# 1         No         No        Yes         No         No          No
# 2         NA         NA         NA         NA         NA          NA
# 3         NA         NA         NA         NA         NA          NA
# 4        Yes         No         No         No         No          No
#
#   qbikestore2 qbikestore3 qbikestore4 qbikestore5 qbikestore6 qbikestore7  \
# 0         Yes         Yes          No          No          No          No
# 1         Yes          No          No          No          No          No
# 2          NA          NA          NA          NA          NA          NA
# 3          NA          NA          NA          NA          NA          NA
# 4          No         Yes          No          No          No          No
#
#   qbikestore8 qbikestore9           qbikeride qbiketo qbikedays qbikewhy1  \
# 0          No          No  A few times a year      No        NA        NA
# 1          No          No               Never      NA        NA        NA
# 2          NA          NA               Never      NA        NA        NA
# 3          NA          NA               Never      NA        NA        NA
# 4          No          No  A few times a year      No        NA        NA
#
#   qbikewhy2 qbikewhy3 qbikewhy4 qbikewhy5 qbikewhy6 qbikewhy7 qbikewhy8  \
# 0        NA        NA        NA        NA        NA        NA        NA
# 1        NA        NA        NA        NA        NA        NA        NA
# 2        NA        NA        NA        NA        NA        NA        NA
# 3        NA        NA        NA        NA        NA        NA        NA
# 4        NA        NA        NA        NA        NA        NA        NA
#
#   qbikewhynot1 qbikewhynot2 qbikewhynot3 qbikewhynot4 qbikewhynot5  \
# 0           No           No           No           No           No
# 1           No           No           No           No           No
# 2           No           No           No           No           No
# 3           No           No           No           No           No
# 4           No           No           No           No           No
#
#   qbikewhynot6 qbikewhynot7 qbikewhynot8 qbikestolen qcitibike qcitibikefreq  \
# 0          Yes           No           No          No        No            NA
# 1          Yes           No           No          No        No            NA
# 2          Yes           No           No          No        No            NA
# 3          Yes           No           No          No        No            NA
# 4          Yes           No           No         Yes        No            NA
#
#   gcitibk1_qcitibikeissues1 gcitibk1_qcitibikeissues2 qnocitibike01  \
# 0                        NA                        NA            No
# 1                        NA                        NA            No
# 2                        NA                        NA            No
# 3                        NA                        NA           Yes
# 4                        NA                        NA            No
#
#   qnocitibike02 qnocitibike03 qnocitibike04 qnocitibike05 qnocitibike06  \
# 0           Yes            No            No            No            No
# 1            No            No           Yes            No            No
# 2           Yes            No            No            No           Yes
# 3            No            No            No            No            No
# 4            No            No           Yes            No            No
#
#   qnocitibike07 qnocitibike08 qnocitibike09 qnocitibike10 qnocitibike11  \
# 0            No            No            No            No            No
# 1            No            No            No            No            No
# 2            No            No            No            No            No
# 3           Yes            No            No            No            No
# 4            No            No            No            No            No
#
#         gfreight1b_qfreight1_ma       gfreight1b_qfreight2_ma  \
# 0  Less than a few times a year                  Once a month
# 1  Less than a few times a year                   Once a week
# 2            A few times a year  Less than a few times a year
# 3  Less than a few times a year                  Once a month
# 4           A few times a month                   Once a week
#
#         gfreight1b_qfreight3_ma gfreight1b_qfreight4_ma qpackagedeliver  \
# 0  Less than a few times a year            Once a month        My lobby
# 1  Less than a few times a year     A few times a month        My lobby
# 2  Less than a few times a year      A few times a year     My doorstep
# 3  Less than a few times a year            Once a month        My lobby
# 4            A few times a year    Several times a week     My doorstep
#
#   qpostalstore    qsubwayservice                     qsubwayimpact  \
# 0           NA     Getting worse  I use the subway the same amount
# 1           NA     Getting worse  I use the subway the same amount
# 2           NA     Getting worse  I use the subway the same amount
# 3           NA     Getting worse  I use the subway the same amount
# 4           NA  Staying the same                                NA
#
#   qtransportnosubway01 qtransportnosubway02 qtransportnosubway03  \
# 0                   NA                   NA                   NA
# 1                   NA                   NA                   NA
# 2                   NA                   NA                   NA
# 3                   NA                   NA                   NA
# 4                   NA                   NA                   NA
#
#   qtransportnosubway04 qtransportnosubway05 qtransportnosubway06  \
# 0                   NA                   NA                   NA
# 1                   NA                   NA                   NA
# 2                   NA                   NA                   NA
# 3                   NA                   NA                   NA
# 4                   NA                   NA                   NA
#
#   qtransportnosubway07 qtransportnosubway08 qtransportnosubway09  \
# 0                   NA                   NA                   NA
# 1                   NA                   NA                   NA
# 2                   NA                   NA                   NA
# 3                   NA                   NA                   NA
# 4                   NA                   NA                   NA
#
#   qtransportnosubway10 qtransportnosubway11       qbusservice  \
# 0                   NA                   NA    Getting better
# 1                   NA                   NA  Staying the same
# 2                   NA                   NA  Staying the same
# 3                   NA                   NA     Getting worse
# 4                   NA                   NA     Getting worse
#
#                        qbusimpact qtransportnobus01 qtransportnobus02  \
# 0  I take the bus the same amount                NA                NA
# 1                              NA                NA                NA
# 2                              NA                NA                NA
# 3  I take the bus the same amount                NA                NA
# 4  I take the bus less frequently                NA                NA
#
#   qtransportnobus03 qtransportnobus04 qtransportnobus05 qtransportnobus06  \
# 0                NA                NA                NA                NA
# 1                NA                NA                NA                NA
# 2                NA                NA                NA                NA
# 3                NA                NA                NA                NA
# 4                NA                NA                NA                NA
#
#   qtransportnobus07 qtransportnobus08 qtransportnobus09 qtransportnobus10  \
# 0                NA                NA                NA                NA
# 1                NA                NA                NA                NA
# 2                NA                NA                NA                NA
# 3                NA                NA                NA                NA
# 4                NA                NA                NA                NA
#
#   qtransportnobus11    qautovehiclefam  qautovehiclewill  \
# 0                NA  Somewhat familiar  Not very willing
# 1                NA  Not very familiar  Not very willing
# 2                NA  Not very familiar  Somewhat willing
# 3                NA  Somewhat familiar  Somewhat willing
# 4                NA  Somewhat familiar  Not very willing
#
#                                     qautovehiclesafe  qmarried qwelfare1  \
# 0  Neither more nor less safe than standard vehicles    Single        No
# 1          Somewhat less safe than standard vehicles   Married        No
# 2  Neither more nor less safe than standard vehicles  Divorced        No
# 3          Somewhat less safe than standard vehicles    Single        No
# 4          Somewhat less safe than standard vehicles   Married        No
#
#   qwelfare2 qwelfare3 qwelfare4 qwelfare5 qdisability1 qdisability2  \
# 0        No       Yes        No        No           No           No
# 1        No       Yes        No        No           No           No
# 2        No       Yes        No        No           No           No
# 3        No       Yes        No        No           No           No
# 4        No       Yes        No        No           No           No
#
#   qdisability3 qdisability4 qdisability5 qdisability6 qdisability7  \
# 0           No           No           No           No          Yes
# 1           No           No           No           No          Yes
# 2           No           No           No           No          Yes
# 3           No           No           No           No          Yes
# 4           No           No           No           No          Yes
#
#   qdisability8 qdisability9                             qbuildingb qrent  \
# 0           No           No      A building with 2 to 9 apartments   Own
# 1           No           No    A building with 10 to 49 apartments   Own
# 2           No           No    A building with 10 to 49 apartments  Rent
# 3           No           No  A building with 50 or more apartments   Own
# 4           No           No  A building with 50 or more apartments   Own
#
#   qchildren gchild1_qchild1_ma gchild1_qchild2_ma gchild1_qchild3_ma  \
# 0      None                 NA                 NA                 NA
# 1      None                 NA                 NA                 NA
# 2      None                 NA                 NA                 NA
# 3      None                 NA                 NA                 NA
# 4      None                 NA                 NA                 NA
#
#   gchild1_qchild4_ma qchild1schooladdr qchild2schooladdr qchild3schooladdr  \
# 0                 NA                NA                NA                NA
# 1                 NA                NA                NA                NA
# 2                 NA                NA                NA                NA
# 3                 NA                NA                NA                NA
# 4                 NA                NA                NA                NA
#
#   qaccompany qschooltravelcode01 qschooltravelcode02 qschooltravelcode03  \
# 0         NA                  NA                  NA                  NA
# 1         NA                  NA                  NA                  NA
# 2         NA                  NA                  NA                  NA
# 3         NA                  NA                  NA                  NA
# 4         NA                  NA                  NA                  NA
#
#   qschooltravelcode04 qschooltravelcode05 qschooltravelcode06  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#   qschooltravelcode07 qschooltravelcode08 qschooltravelcode09  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#   qschooltravelcode10 qschooltravelcode11 qschooltravelcode12  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#   qschooltravelcode13 qschooltravelcode14 qschooltravelcode15  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#   qschooltravelcode16 qschooltravelcode17 qschooltravelcode18  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#   qschooltravelcode19 qschooltravelcode20 qschooltravelcode21  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#   qschooltravelcode22 qschooltravelcode23 qschooltravelcode24  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#   qschooltravelcode25 qschooltravelcode26 qschooltravelcode27  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#   qschooltransitto1 qschooltransitto2 qschooltransitto3 qschooltransitto4  \
# 0                NA                NA                NA                NA
# 1                NA                NA                NA                NA
# 2                NA                NA                NA                NA
# 3                NA                NA                NA                NA
# 4                NA                NA                NA                NA
#
#   qschooltransitto5 qschooltransitto6 qschooltransitto7 qschooltransitfrom1  \
# 0                NA                NA                NA                  NA
# 1                NA                NA                NA                  NA
# 2                NA                NA                NA                  NA
# 3                NA                NA                NA                  NA
# 4                NA                NA                NA                  NA
#
#   qschooltransitfrom2 qschooltransitfrom3 qschooltransitfrom4  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#   qschooltransitfrom5 qschooltransitfrom6 qschooltransitfrom7  \
# 0                  NA                  NA                  NA
# 1                  NA                  NA                  NA
# 2                  NA                  NA                  NA
# 3                  NA                  NA                  NA
# 4                  NA                  NA                  NA
#
#                                          qemployment     qemploymentcode  \
# 0  Employed full time (working more than 30 hours...            Employed
# 1                                         Unemployed          Unemployed
# 2                                            Retired  Not in Labor Force
# 3                                            Retired  Not in Labor Force
# 4  Employed full time (working more than 30 hours...            Employed
#
#     qindustry gfulltime_qfulltime_ma gfulltime_qparttime_ma qnumberofjobs  \
# 0  Non-profit                      1                      0         1 job
# 1          NA                     NA                     NA            NA
# 2          NA                     NA                     NA            NA
# 3          NA                     NA                     NA            NA
# 4   Education                      1                      0         1 job
#
#                       qworklocation                    qworkfh qborough_work1  \
# 0                      At an office  No, do not work from home      Manhattan
# 1                                NA                         NA             NA
# 2                                NA                         NA             NA
# 3                                NA                         NA             NA
# 4  At a school or day care facility  No, do not work from home       Brooklyn
#
#   qntacode_work qtimework qtimehome qborough_work2 qborough_work3  \
# 0          MN40   8:15 AM   7:00 PM             NA             NA
# 1           NaN       NaN       NaN             NA             NA
# 2           NaN       NaN       NaN             NA             NA
# 3           NaN       NaN       NaN             NA             NA
# 4          BK17    6:45AM    5"30PM             NA             NA
#
#   qworktravelcode01 qworktravelcode02 qworktravelcode03 qworktravelcode04  \
# 0               Yes               Yes                No                No
# 1                NA                NA                NA                NA
# 2                NA                NA                NA                NA
# 3                NA                NA                NA                NA
# 4                No               Yes                No                No
#
#   qworktravelcode05 qworktravelcode06 qworktravelcode07 qworktravelcode08  \
# 0                No                No                No                No
# 1                NA                NA                NA                NA
# 2                NA                NA                NA                NA
# 3                NA                NA                NA                NA
# 4                No                No                No                No
#
#   qworktravelcode09 qworktravelcode10 qworktravelcode11 qworktravelcode12  \
# 0                No                No                No                No
# 1                NA                NA                NA                NA
# 2                NA                NA                NA                NA
# 3                NA                NA                NA                NA
# 4                No                No                No                No
#
#   qworktravelcode13 qworktravelcode14 qworktravelcode15 qworktravelcode16  \
# 0                No                No                No                No
# 1                NA                NA                NA                NA
# 2                NA                NA                NA                NA
# 3                NA                NA                NA                NA
# 4                No                No                No                No
#
#   qworktravelcode17 qworktravelcode18 qworktravelcode19 qworktravelcode20  \
# 0                No                No                No                No
# 1                NA                NA                NA                NA
# 2                NA                NA                NA                NA
# 3                NA                NA                NA                NA
# 4                No                No                No                No
#
#   qworktravelcode21 qworktravelcode22 qworktravelcode23 qworktravelcode24  \
# 0                No                No                No                No
# 1                NA                NA                NA                NA
# 2                NA                NA                NA                NA
# 3                NA                NA                NA                NA
# 4                No                No                No                No
#
#   qworktravelcode25 qworktravelcode26 qworkcarpark qworkparkpay qworkbikepark  \
# 0                No                No           NA           NA            NA
# 1                NA                NA           NA           NA            NA
# 2                NA                NA           NA           NA            NA
# 3                NA                NA           NA           NA            NA
# 4                No                No           NA           NA            NA
#
#                       qschool qlevelschool qborough_school  \
# 0  No, I do not attend school           NA              NA
# 1  No, I do not attend school           NA              NA
# 2  No, I do not attend school           NA              NA
# 3  No, I do not attend school           NA              NA
# 4  No, I do not attend school           NA              NA
#
#   qstudenttravelcode01 qstudenttravelcode02 qstudenttravelcode03  \
# 0                   No                   No                   No
# 1                   No                   No                   No
# 2                   No                   No                   No
# 3                   No                   No                   No
# 4                   No                   No                   No
#
#   qstudenttravelcode04 qstudenttravelcode05 qstudenttravelcode06  \
# 0                   No                   No                   No
# 1                   No                   No                   No
# 2                   No                   No                   No
# 3                   No                   No                   No
# 4                   No                   No                   No
#
#   qstudenttravelcode07 qstudenttravelcode08 qstudenttravelcode09  \
# 0                   No                   No                   No
# 1                   No                   No                   No
# 2                   No                   No                   No
# 3                   No                   No                   No
# 4                   No                   No                   No
#
#   qstudenttravelcode10 qstudenttravelcode11 qstudenttravelcode12  \
# 0                   No                   No                   No
# 1                   No                   No                   No
# 2                   No                   No                   No
# 3                   No                   No                   No
# 4                   No                   No                   No
#
#   qstudenttravelcode13 qstudenttravelcode14 qstudenttravelcode15  \
# 0                   No                   No                   No
# 1                   No                   No                   No
# 2                   No                   No                   No
# 3                   No                   No                   No
# 4                   No                   No                   No
#
#   qstudenttravelcode16 qstudenttravelcode17 qstudenttravelcode18  \
# 0                   No                   No                   No
# 1                   No                   No                   No
# 2                   No                   No                   No
# 3                   No                   No                   No
# 4                   No                   No                   No
#
#   qstudenttravelcode19 qstudenttravelcode20 qstudenttravelcode21  \
# 0                   No                   No                   No
# 1                   No                   No                   No
# 2                   No                   No                   No
# 3                   No                   No                   No
# 4                   No                   No                   No
#
#   qstudenttravelcode22 qstudenttravelcode23 qstudenttravelcode24  \
# 0                   No                   No                   No
# 1                   No                   No                   No
# 2                   No                   No                   No
# 3                   No                   No                   No
# 4                   No                   No                   No
#
#   qstudenttravelcode25 qstudenttravelcode26 qstudentpark qstudentparkpay  \
# 0                   No                   No           NA              NA
# 1                   No                   No           NA              NA
# 2                   No                   No           NA              NA
# 3                   No                   No           NA              NA
# 4                   No                   No           NA              NA
#
#   qstudentbikepark qlanguagepref qlanguage2 qfreight_cmb1 qfreight_cmb2  \
# 0               NA       English         NA            No            No
# 1               NA       English         NA            No            No
# 2               NA       English         NA            No            No
# 3               NA            NA         NA            No            No
# 4               NA            NA         NA            No           Yes
#
#   qfreight_cmb3 qfreight_cmb4 qfreight_cmb5 qfreight_cmb6 qfreight_cmb7  \
# 0            No            No           Yes            No           Yes
# 1           Yes           Yes            No            No           Yes
# 2            No            No            No           Yes           Yes
# 3            No            No           Yes            No           Yes
# 4           Yes           Yes            No           Yes            No
#
#   qfreight_cmb8 qfreight_cmb9        allwt qntacode_work2 qtimework2  \
# 0            No            No   0.28805089            NaN        NaN
# 1            No            No  1.223591243            NaN        NaN
# 2            No            No  0.409953952            NaN        NaN
# 3            No            No  2.398325338            NaN        NaN
# 4            No            No  0.767818787            NaN        NaN
#
#   qtimehome2 qntacode_school qntacode_work3 qtimework3 qtimehome3  \
# 0        NaN             NaN            NaN        NaN        NaN
# 1        NaN             NaN            NaN        NaN        NaN
# 2        NaN             NaN            NaN        NaN        NaN
# 3        NaN             NaN            NaN        NaN        NaN
# 4        NaN             NaN            NaN        NaN        NaN
#
#   qchild4schooladdr
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
trip_diary_df.to_csv('trip_diary.csv')

# %%
main_survey_df.to_csv('main_survey.csv')

# %% [markdown]
# # EDA: Trips

# %%
trip_diary_df.shape
# Out:
# (7977, 118)

# %%
print(trip_diary_df.dtypes)
# Out:
# job                           object
# trip_id                       object
# uniqueid                      object
# qday                          object
# qday1typical                  object
# qborough_home                 object
# qsurveyzone_home              object
# qtripdaytime                  object
# qday1tripstartcode            object
# qday1tripstartam              object
# qday1tripstartnoon            object
# qday1tripstartpm              object
# qday1trip_outsidenyc_start    object
# qborough_start                object
# qntacode_start                object
# surveyzone_start              object
# qday1tripend                  object
# qday1trip_outsidenyc_end      object
# qborough_end                  object
# qntacode_end                  object
# surveyzone_end                object
# qday1tripendcode              object
# qday1triptransitto1           object
# qday1triptransitto2           object
# qday1triptransitto3           object
# qday1triptransitto4           object
# qday1triptransitto5           object
# qday1triptransitto6           object
# qday1triptransitto7           object
# qday1triptransitfrom1         object
# qday1triptransitfrom2         object
# qday1triptransitfrom3         object
# qday1triptransitfrom4         object
# qday1triptransitfrom5         object
# qday1triptransitfrom6         object
# qday1triptransitfrom7         object
# qday1triptravelcode01         object
# qday1triptravelcode02         object
# qday1triptravelcode03         object
# qday1triptravelcode04         object
# qday1triptravelcode05         object
# qday1triptravelcode06         object
# qday1triptravelcode07         object
# qday1triptravelcode08         object
# qday1triptravelcode09         object
# qday1triptravelcode10         object
# qday1triptravelcode11         object
# qday1triptravelcode12         object
# qday1triptravelcode13         object
# qday1triptravelcode14         object
# qday1triptravelcode15         object
# qday1triptravelcode16         object
# qday1triptravelcode17         object
# qday1triptravelcode18         object
# qday1triptravelcode19         object
# qday1triptravelcode20         object
# qday1triptravelcode21         object
# qday1triptravelcode22         object
# qday1triptravelcode23         object
# qday1triptravelcode24         object
# qday1triptravelcode25         object
# qday1triptravelcode26         object
# qday1triptravelcode27         object
# qday1trippurpose              object
# qday1triplength               object
# qday1triplength_flt           object
# qday1triplength_cat           object
# qday1trippark                 object
# qday1tripparkpay              object
# qday1tripparkpay_amount       object
# qday1tripbikestore            object
# number_of_trips_taken         object
# qgender                       object
# qincome                       object
# qdisability1                  object
# qdisability2                  object
# qdisability3                  object
# qdisability4                  object
# qdisability5                  object
# qdisability6                  object
# qdisability7                  object
# qdisability8                  object
# qdisability9                  object
# qage                          object
# qagecode                      object
# qrace                         object
# qracecode                     object
# qhispanic                     object
# qeducation                    object
# qlicense                      object
# qcaraccess                    object
# qcarchange                    object
# qwelfare1                     object
# qwelfare2                     object
# qwelfare3                     object
# qwelfare4                     object
# qwelfare5                     object
# qsmartphone                   object
# qshare1                       object
# qshare2                       object
# qshare3                       object
# qshare4                       object
# qshare5                       object
# qshare6                       object
# qshare7                       object
# qshare8                       object
# qtemphigh                     object
# qtemplow                      object
# qprecipitation                object
# qsunrise                      object
# qsunset                       object
# qcitibike                     object
# qday1triptravelcode_sp        object
# qmodegrouping                 object
# qsustainablemode              object
# allwt                         object
# qpurposerecode                object
# ntacode_home                  object
# dtype: object

# %%
trip_diary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7977 entries, 0 to 7976
# Columns: 118 entries, job to ntacode_home
# dtypes: object(118)
# memory usage: 7.2+ MB

# %%
trip_diary_df.isna().sum()
# Out:
# job                              0
# trip_id                          0
# uniqueid                         0
# qday                             0
# qday1typical                     0
# qborough_home                    0
# qsurveyzone_home                 0
# qtripdaytime                     0
# qday1tripstartcode               0
# qday1tripstartam                 0
# qday1tripstartnoon               0
# qday1tripstartpm                 0
# qday1trip_outsidenyc_start       0
# qborough_start                   0
# qntacode_start                5774
# surveyzone_start                 0
# qday1tripend                     0
# qday1trip_outsidenyc_end         0
# qborough_end                     0
# qntacode_end                  5775
# surveyzone_end                   0
# qday1tripendcode                 0
# qday1triptransitto1              0
# qday1triptransitto2              0
# qday1triptransitto3              0
# qday1triptransitto4              0
# qday1triptransitto5              0
# qday1triptransitto6              0
# qday1triptransitto7              0
# qday1triptransitfrom1            0
# qday1triptransitfrom2            0
# qday1triptransitfrom3            0
# qday1triptransitfrom4            0
# qday1triptransitfrom5            0
# qday1triptransitfrom6            0
# qday1triptransitfrom7            0
# qday1triptravelcode01            0
# qday1triptravelcode02            0
# qday1triptravelcode03            0
# qday1triptravelcode04            0
# qday1triptravelcode05            0
# qday1triptravelcode06            0
# qday1triptravelcode07            0
# qday1triptravelcode08            0
# qday1triptravelcode09            0
# qday1triptravelcode10            0
# qday1triptravelcode11            0
# qday1triptravelcode12            0
# qday1triptravelcode13            0
# qday1triptravelcode14            0
# qday1triptravelcode15            0
# qday1triptravelcode16            0
# qday1triptravelcode17            0
# qday1triptravelcode18            0
# qday1triptravelcode19            0
# qday1triptravelcode20            0
# qday1triptravelcode21            0
# qday1triptravelcode22            0
# qday1triptravelcode23            0
# qday1triptravelcode24            0
# qday1triptravelcode25            0
# qday1triptravelcode26            0
# qday1triptravelcode27            0
# qday1trippurpose                 0
# qday1triplength                  0
# qday1triplength_flt              0
# qday1triplength_cat              0
# qday1trippark                    0
# qday1tripparkpay                 0
# qday1tripparkpay_amount          0
# qday1tripbikestore               0
# number_of_trips_taken            0
# qgender                          0
# qincome                          0
# qdisability1                     0
# qdisability2                     0
# qdisability3                     0
# qdisability4                     0
# qdisability5                     0
# qdisability6                     0
# qdisability7                     0
# qdisability8                     0
# qdisability9                     0
# qage                             0
# qagecode                         0
# qrace                            0
# qracecode                        0
# qhispanic                        0
# qeducation                       0
# qlicense                         0
# qcaraccess                       0
# qcarchange                       0
# qwelfare1                        0
# qwelfare2                        0
# qwelfare3                        0
# qwelfare4                        0
# qwelfare5                        0
# qsmartphone                      0
# qshare1                          0
# qshare2                          0
# qshare3                          0
# qshare4                          0
# qshare5                          0
# qshare6                          0
# qshare7                          0
# qshare8                          0
# qtemphigh                        0
# qtemplow                         0
# qprecipitation                   0
# qsunrise                         0
# qsunset                          0
# qcitibike                        0
# qday1triptravelcode_sp           0
# qmodegrouping                    0
# qsustainablemode                 0
# allwt                            0
# qpurposerecode                   0
# ntacode_home                  4945
# dtype: int64

# %%
trip_diary_df.qday.value_counts()
# Out:
# Friday       1347
# Saturday     1241
# Wednesday    1181
# Monday       1155
# Thursday     1154
# Sunday        969
# Tuesday       930
# Name: qday, dtype: int64

# %%
trip_diary_df.ntacode_home.value_counts()
# Out:
# BK88    75
# MN12    67
# BK37    63
# MN03    58
# BK82    47
# MN13    46
# BK91    45
# QN12    43
# MN36    41
# BK61    41
# BK33    40
# QN08    40
# BK31    39
# BK35    37
# BK60    37
# BK75    36
# MN35    36
# MN32    36
# BK95    36
# BK78    34
# BK50    32
# BX14    31
# BX52    30
# MN34    29
# MN33    28
# BX34    28
# MN14    28
# BX05    27
# BX33    27
# BK73    27
# BX46    26
# BX09    26
# QN15    25
# BK58    25
# MN23    25
# SI05    25
# MN22    25
# BK81    25
# MN04    24
# BK64    24
# BK96    23
# QN21    23
# MN40    23
# BK29    22
# MN15    22
# BX41    22
# MN01    22
# BX37    21
# QN10    21
# MN17    21
# BX03    21
# BX13    21
# BX36    20
# QN19    19
# BX43    19
# QN28    19
# BX62    19
# QN31    19
# MN11    19
# BK32    19
# QN17    18
# BK42    18
# BK85    18
# BK45    18
# BK69    18
# BK25    18
# QN34    17
# MN31    17
# BX35    17
# MN19    17
# BX44    17
# QN55    17
# MN09    17
# QN29    17
# QN72    16
# QN30    16
# BK46    16
# BX63    16
# MN06    16
# QN54    16
# QN51    16
# BK40    16
# SI12    16
# MN20    16
# BK68    15
# SI08    15
# QN53    15
# BK44    15
# SI07    14
# BK17    14
# BX26    14
# QN46    14
# BK38    14
# MN21    14
# BX08    14
# BK77    14
# SI36    13
# SI22    13
# SI14    13
# QN22    13
# QN61    13
# MN28    13
# BK76    13
# BX17    13
# BX75    12
# MN24    12
# BX28    12
# QN71    12
# BX30    11
# BK83    11
# QN20    11
# QN38    11
# QN06    11
# BK79    11
# BX01    10
# BK34    10
# QN35    10
# QN49    10
# QN70    10
# BK27     9
# QN33     9
# QN45     9
# QN76     9
# BK72     8
# BX22     8
# BX06     8
# MN25     8
# BX29     7
# QN23     7
# BK63     7
# SI54     7
# SI01     7
# QN66     7
# QN05     7
# QN26     7
# BX40     7
# N/A      7
# BK28     7
# QN25     7
# BK93     6
# BK41     6
# BX27     6
# QN37     6
# BX55     6
# BX10     6
# QN57     6
# SI28     6
# QN43     6
# BK90     6
# QN44     6
# BX31     6
# SI24     6
# BK99     6
# QN63     6
# SI32     6
# BK26     6
# BX07     5
# SI48     5
# BX39     5
# QN48     5
# BK30     5
# QN07     4
# SI45     4
# QN60     4
# QN01     4
# QN50     4
# SI11     4
# QN56     4
# QN99     4
# QN03     3
# MN50     3
# QN41     3
# MN27     3
# SI25     3
# SI35     2
# QN52     2
# BK43     2
# BX49     2
# BK19     2
# BK21     2
# QN02     1
# Name: ntacode_home, dtype: int64

# %%
trip_diary_df.qday1trippurpose.value_counts()
# Out:
# Commute to/from work               2499
# Other                              1140
# Social/recreation                  1081
# Shopping                           1051
# Personal errands                    803
# Dining                              434
# School                              291
# Medical visit (doctor's office)     285
# Business                            270
# Accompanying other traveler          71
# NA                                   41
# Refused                              11
# Name: qday1trippurpose, dtype: int64

# %%
#make bar graph of day of week counts
# fig, ax = plt.subplots()

# # Plot a bar-chart of gold medals as a function of country
# ax.bar(['Males', 'Females'], [males['Height'].mean(), females['Height'].mean()], yerr= [males['Height'].std(), females['Height'].std(),])

# # Set the x-axis tick labels to the country names
# ax.set_xticklabels(['Males', 'Females'], rotation=90)

# # Set the y-axis label
# ax.set_ylabel("Height (cm)")

# ax.set_title('Comparing Height by Gender')

# plt.show()

# %% [markdown]
# Clean Data

# %%
#drop irrelevant columns
drop_cols_trip_diary_df = trip_diary_df.drop(columns=['job', 'qday1tripstartcode', 'qday1tripstartcode', 'qday1tripstartam',
                                            'qday1tripstartnoon', 'qday1tripstartpm', 'qday1trip_outsidenyc_start',
                                            'qday1trip_outsidenyc_end', 'qday1triptransitto1', 'qday1triptransitto2',
                                            'qday1triptransitto3', 'qday1triptransitto4', 'qday1triptransitto5',
                                            'qday1triptransitto6', 'qday1triptransitto7', 'qday1triptransitfrom1',
                                            'qday1triptransitfrom2', 'qday1triptransitfrom3', 'qday1triptransitfrom4',
                                            'qday1triptransitfrom5', 'qday1triptransitfrom6', 'qday1triptransitfrom7',
                                            'qday1triptravelcode01', 'qday1triptravelcode02', 'qday1triptravelcode03',
                                            'qday1triptravelcode04', 'qday1triptravelcode05', 'qday1triptravelcode06',
                                            'qday1triptravelcode07', 'qday1triptravelcode08', 'qday1triptravelcode09',
                                            'qday1triptravelcode10', 'qday1triptravelcode11', 'qday1triptravelcode12',
                                            'qday1triptravelcode13', 'qday1triptravelcode14', 'qday1triptravelcode15',
                                            'qday1triptravelcode16', 'qday1triptravelcode17', 'qday1triptravelcode18',
                                            'qday1triptravelcode19', 'qday1triptravelcode20', 'qday1triptravelcode21',
                                            'qday1triptravelcode22', 'qday1triptravelcode23', 'qday1triptravelcode24',
                                            'qday1triptravelcode25', 'qday1triptravelcode26', 'qday1triptravelcode27',
                                            'qday1trippurpose', 'qday1triplength', 'qday1triplength_flt','qday1trippark',
                                            'qday1tripparkpay_amount', 'qday1tripbikestore','qage', 'qrace', 'qhispanic',
                                            'qcarchange', 'qsunrise', 'qsunset', 'qday1tripparkpay'])

# %%
drop_cols_trip_diary_df.head()
# Out:
#     trip_id  uniqueid      qday  qday1typical qborough_home qsurveyzone_home  \
# 0   3101674    101674    Sunday            NA        Queens    Middle Queens
# 1  11202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 2  12202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 3  51200330  50200330  Thursday  Very typical        Queens    Middle Queens
# 4  52200330  50200330  Thursday  Very typical        Queens    Middle Queens
#
#   qtripdaytime qborough_start qntacode_start surveyzone_start  \
# 0         NOON         Queens           QN43     Outer Queens
# 1           AM         Queens            NaN               NA
# 2         NOON             NA            NaN               NA
# 3           AM         Queens            NaN    Middle Queens
# 4           AM         Queens            NaN    Middle Queens
#
#                  qday1tripend qborough_end qntacode_end surveyzone_end  \
# 0                        Home       Queens         QN76   Outer Queens
# 1                        Home           NA          NaN             NA
# 2  Park/Recreational area/Gym       Queens          NaN             NA
# 3  Park/Recreational area/Gym       Queens          NaN  Middle Queens
# 4                        Home       Queens          NaN  Middle Queens
#
#              qday1tripendcode qday1triplength_cat number_of_trips_taken  \
# 0                        Home            11 to 15               3 trips
# 1                        Home            26 to 30               3 trips
# 2  Park/Recreational area/Gym            16 to 20               3 trips
# 3  Park/Recreational area/Gym            11 to 15               4 trips
# 4                        Home            11 to 15               4 trips
#
#   qgender            qincome qdisability1 qdisability2 qdisability3  \
# 0    Male  $50,000 - $74,999           No           No           No
# 1    Male  $50,000 - $74,999           No           No           No
# 2    Male  $50,000 - $74,999           No           No           No
# 3    Male  $50,000 - $74,999           No           No           No
# 4    Male  $50,000 - $74,999           No           No           No
#
#   qdisability4 qdisability5 qdisability6 qdisability7 qdisability8  \
# 0          Yes           No           No           No           No
# 1           No           No           No          Yes           No
# 2           No           No           No          Yes           No
# 3           No           No           No          Yes           No
# 4           No           No           No          Yes           No
#
#   qdisability9 qagecode            qracecode  \
# 0           No    25-34  White, Non-Hispanic
# 1           No    25-34  Black, Non-Hispanic
# 2           No    25-34  Black, Non-Hispanic
# 3           No    55-64  White, Non-Hispanic
# 4           No    55-64  White, Non-Hispanic
#
#                                        qeducation qlicense  \
# 0  High school graduate or equivalent (i.e., GED)      Yes
# 1            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 2            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 3  High school graduate or equivalent (i.e., GED)      Yes
# 4  High school graduate or equivalent (i.e., GED)      Yes
#
#                         qcaraccess qwelfare1 qwelfare2 qwelfare3 qwelfare4  \
# 0    I do not have access to a car        No       Yes        No        No
# 1  I personally own or lease a car        No        No       Yes        No
# 2  I personally own or lease a car        No        No       Yes        No
# 3  I personally own or lease a car        No        No       Yes        No
# 4  I personally own or lease a car        No        No       Yes        No
#
#   qwelfare5 qsmartphone qshare1 qshare2 qshare3 qshare4 qshare5 qshare6  \
# 0        No         Yes     Yes      No      No      No      No      No
# 1        No         Yes      No      No      No      No      No     Yes
# 2        No         Yes      No      No      No      No      No     Yes
# 3        No          No      No      No      No      No      No     Yes
# 4        No          No      No      No      No      No      No     Yes
#
#   qshare7 qshare8 qtemphigh qtemplow qprecipitation qcitibike  \
# 0      No      No        79       58              0        NA
# 1      No      No        66       51           0.25        No
# 2      No      No        66       51           0.25        No
# 3      No      No        73       57              0        No
# 4      No      No        73       57              0        No
#
#   qday1triptravelcode_sp qmodegrouping qsustainablemode        allwt  \
# 0              Citi Bike          Bike              Yes  2.269122796
# 1       Personal bicycle          Bike              Yes  0.868686684
# 2       Personal bicycle          Bike              Yes  0.868686684
# 3       Personal bicycle          Bike              Yes   2.43311884
# 4       Personal bicycle          Bike              Yes   2.43311884
#
#          qpurposerecode ntacode_home
# 0                School          NaN
# 1  Commute to/from work          NaN
# 2     Social/recreation          NaN
# 3     Social/recreation         QN60
# 4     Social/recreation         QN60

# %%
drop_cols_trip_diary_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7977 entries, 0 to 7976
# Data columns (total 57 columns):
# trip_id                   7977 non-null object
# uniqueid                  7977 non-null object
# qday                      7977 non-null object
# qday1typical              7977 non-null object
# qborough_home             7977 non-null object
# qsurveyzone_home          7977 non-null object
# qtripdaytime              7977 non-null object
# qborough_start            7977 non-null object
# qntacode_start            2203 non-null object
# surveyzone_start          7977 non-null object
# qday1tripend              7977 non-null object
# qborough_end              7977 non-null object
# qntacode_end              2202 non-null object
# surveyzone_end            7977 non-null object
# qday1tripendcode          7977 non-null object
# qday1triplength_cat       7977 non-null object
# number_of_trips_taken     7977 non-null object
# qgender                   7977 non-null object
# qincome                   7977 non-null object
# qdisability1              7977 non-null object
# qdisability2              7977 non-null object
# qdisability3              7977 non-null object
# qdisability4              7977 non-null object
# qdisability5              7977 non-null object
# qdisability6              7977 non-null object
# qdisability7              7977 non-null object
# qdisability8              7977 non-null object
# qdisability9              7977 non-null object
# qagecode                  7977 non-null object
# qracecode                 7977 non-null object
# qeducation                7977 non-null object
# qlicense                  7977 non-null object
# qcaraccess                7977 non-null object
# qwelfare1                 7977 non-null object
# qwelfare2                 7977 non-null object
# qwelfare3                 7977 non-null object
# qwelfare4                 7977 non-null object
# qwelfare5                 7977 non-null object
# qsmartphone               7977 non-null object
# qshare1                   7977 non-null object
# qshare2                   7977 non-null object
# qshare3                   7977 non-null object
# qshare4                   7977 non-null object
# qshare5                   7977 non-null object
# qshare6                   7977 non-null object
# qshare7                   7977 non-null object
# qshare8                   7977 non-null object
# qtemphigh                 7977 non-null object
# qtemplow                  7977 non-null object
# qprecipitation            7977 non-null object
# qcitibike                 7977 non-null object
# qday1triptravelcode_sp    7977 non-null object
# qmodegrouping             7977 non-null object
# qsustainablemode          7977 non-null object
# allwt                     7977 non-null object
# qpurposerecode            7977 non-null object
# ntacode_home              3032 non-null object
# dtypes: object(57)
# memory usage: 3.5+ MB

# %%
drop_cols_trip_diary_df['qday1typical']= drop_cols_trip_diary_df['qday1typical'].replace('Very Typical', 'Very typical')
drop_cols_trip_diary_df['qday1tripend']= drop_cols_trip_diary_df['qday1tripend'].replace('NA', 'Home')
drop_cols_trip_diary_df['qday1tripendcode']= drop_cols_trip_diary_df['qday1tripendcode'].replace('NA', 'Home')
drop_cols_trip_diary_df['qincome']= drop_cols_trip_diary_df['qincome'].replace('NA', '$50,000 - $74,999')
drop_cols_trip_diary_df['qeducation']= drop_cols_trip_diary_df['qeducation'].replace('9', "Bachelor's degree (i.e., BA, BS, AB)")
drop_cols_trip_diary_df['qlicense']= drop_cols_trip_diary_df['qlicense'].replace('NA', 'Yes')
drop_cols_trip_diary_df['qcaraccess']= drop_cols_trip_diary_df['qcaraccess'].replace('NA', 'I personally own or lease a car')
drop_cols_trip_diary_df['qwelfare2']= drop_cols_trip_diary_df['qwelfare2'].replace('NA', 'Yes')
drop_cols_trip_diary_df['qsmartphone']= drop_cols_trip_diary_df['qsmartphone'].replace('NA', 'Yes')
drop_cols_trip_diary_df['qcitibike']= drop_cols_trip_diary_df['qcitibike'].replace('NA', 'No')
drop_cols_trip_diary_df['qpurposerecode']= drop_cols_trip_diary_df['qpurposerecode'].replace('NA', 'Commute to/from work')

# %%
drop_cols_trip_diary_df.head()
# Out:
#     trip_id  uniqueid      qday  qday1typical qborough_home qsurveyzone_home  \
# 0   3101674    101674    Sunday            NA        Queens    Middle Queens
# 1  11202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 2  12202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 3  51200330  50200330  Thursday  Very typical        Queens    Middle Queens
# 4  52200330  50200330  Thursday  Very typical        Queens    Middle Queens
#
#   qtripdaytime qborough_start qntacode_start surveyzone_start  \
# 0         NOON         Queens           QN43     Outer Queens
# 1           AM         Queens            NaN               NA
# 2         NOON             NA            NaN               NA
# 3           AM         Queens            NaN    Middle Queens
# 4           AM         Queens            NaN    Middle Queens
#
#                  qday1tripend qborough_end qntacode_end surveyzone_end  \
# 0                        Home       Queens         QN76   Outer Queens
# 1                        Home           NA          NaN             NA
# 2  Park/Recreational area/Gym       Queens          NaN             NA
# 3  Park/Recreational area/Gym       Queens          NaN  Middle Queens
# 4                        Home       Queens          NaN  Middle Queens
#
#              qday1tripendcode qday1triplength_cat number_of_trips_taken  \
# 0                        Home            11 to 15               3 trips
# 1                        Home            26 to 30               3 trips
# 2  Park/Recreational area/Gym            16 to 20               3 trips
# 3  Park/Recreational area/Gym            11 to 15               4 trips
# 4                        Home            11 to 15               4 trips
#
#   qgender            qincome qdisability1 qdisability2 qdisability3  \
# 0    Male  $50,000 - $74,999           No           No           No
# 1    Male  $50,000 - $74,999           No           No           No
# 2    Male  $50,000 - $74,999           No           No           No
# 3    Male  $50,000 - $74,999           No           No           No
# 4    Male  $50,000 - $74,999           No           No           No
#
#   qdisability4 qdisability5 qdisability6 qdisability7 qdisability8  \
# 0          Yes           No           No           No           No
# 1           No           No           No          Yes           No
# 2           No           No           No          Yes           No
# 3           No           No           No          Yes           No
# 4           No           No           No          Yes           No
#
#   qdisability9 qagecode            qracecode  \
# 0           No    25-34  White, Non-Hispanic
# 1           No    25-34  Black, Non-Hispanic
# 2           No    25-34  Black, Non-Hispanic
# 3           No    55-64  White, Non-Hispanic
# 4           No    55-64  White, Non-Hispanic
#
#                                        qeducation qlicense  \
# 0  High school graduate or equivalent (i.e., GED)      Yes
# 1            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 2            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 3  High school graduate or equivalent (i.e., GED)      Yes
# 4  High school graduate or equivalent (i.e., GED)      Yes
#
#                         qcaraccess qwelfare1 qwelfare2 qwelfare3 qwelfare4  \
# 0    I do not have access to a car        No       Yes        No        No
# 1  I personally own or lease a car        No        No       Yes        No
# 2  I personally own or lease a car        No        No       Yes        No
# 3  I personally own or lease a car        No        No       Yes        No
# 4  I personally own or lease a car        No        No       Yes        No
#
#   qwelfare5 qsmartphone qshare1 qshare2 qshare3 qshare4 qshare5 qshare6  \
# 0        No         Yes     Yes      No      No      No      No      No
# 1        No         Yes      No      No      No      No      No     Yes
# 2        No         Yes      No      No      No      No      No     Yes
# 3        No          No      No      No      No      No      No     Yes
# 4        No          No      No      No      No      No      No     Yes
#
#   qshare7 qshare8 qtemphigh qtemplow qprecipitation qcitibike  \
# 0      No      No        79       58              0        No
# 1      No      No        66       51           0.25        No
# 2      No      No        66       51           0.25        No
# 3      No      No        73       57              0        No
# 4      No      No        73       57              0        No
#
#   qday1triptravelcode_sp qmodegrouping qsustainablemode        allwt  \
# 0              Citi Bike          Bike              Yes  2.269122796
# 1       Personal bicycle          Bike              Yes  0.868686684
# 2       Personal bicycle          Bike              Yes  0.868686684
# 3       Personal bicycle          Bike              Yes   2.43311884
# 4       Personal bicycle          Bike              Yes   2.43311884
#
#          qpurposerecode ntacode_home
# 0                School          NaN
# 1  Commute to/from work          NaN
# 2     Social/recreation          NaN
# 3     Social/recreation         QN60
# 4     Social/recreation         QN60

# %%
drop_cols_trip_diary_df.head()
# Out:
#     trip_id  uniqueid      qday  qday1typical qborough_home qsurveyzone_home  \
# 0   3101674    101674    Sunday            NA        Queens    Middle Queens
# 1  11202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 2  12202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 3  51200330  50200330  Thursday  Very typical        Queens    Middle Queens
# 4  52200330  50200330  Thursday  Very typical        Queens    Middle Queens
#
#   qtripdaytime qborough_start qntacode_start surveyzone_start  \
# 0         NOON         Queens           QN43     Outer Queens
# 1           AM         Queens            NaN               NA
# 2         NOON             NA            NaN               NA
# 3           AM         Queens            NaN    Middle Queens
# 4           AM         Queens            NaN    Middle Queens
#
#                  qday1tripend qborough_end qntacode_end surveyzone_end  \
# 0                        Home       Queens         QN76   Outer Queens
# 1                        Home           NA          NaN             NA
# 2  Park/Recreational area/Gym       Queens          NaN             NA
# 3  Park/Recreational area/Gym       Queens          NaN  Middle Queens
# 4                        Home       Queens          NaN  Middle Queens
#
#              qday1tripendcode qday1triplength_cat number_of_trips_taken  \
# 0                        Home            11 to 15               3 trips
# 1                        Home            26 to 30               3 trips
# 2  Park/Recreational area/Gym            16 to 20               3 trips
# 3  Park/Recreational area/Gym            11 to 15               4 trips
# 4                        Home            11 to 15               4 trips
#
#   qgender            qincome qdisability1 qdisability2 qdisability3  \
# 0    Male  $50,000 - $74,999           No           No           No
# 1    Male  $50,000 - $74,999           No           No           No
# 2    Male  $50,000 - $74,999           No           No           No
# 3    Male  $50,000 - $74,999           No           No           No
# 4    Male  $50,000 - $74,999           No           No           No
#
#   qdisability4 qdisability5 qdisability6 qdisability7 qdisability8  \
# 0          Yes           No           No           No           No
# 1           No           No           No          Yes           No
# 2           No           No           No          Yes           No
# 3           No           No           No          Yes           No
# 4           No           No           No          Yes           No
#
#   qdisability9 qagecode            qracecode  \
# 0           No    25-34  White, Non-Hispanic
# 1           No    25-34  Black, Non-Hispanic
# 2           No    25-34  Black, Non-Hispanic
# 3           No    55-64  White, Non-Hispanic
# 4           No    55-64  White, Non-Hispanic
#
#                                        qeducation qlicense  \
# 0  High school graduate or equivalent (i.e., GED)      Yes
# 1            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 2            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 3  High school graduate or equivalent (i.e., GED)      Yes
# 4  High school graduate or equivalent (i.e., GED)      Yes
#
#                         qcaraccess qwelfare1 qwelfare2 qwelfare3 qwelfare4  \
# 0    I do not have access to a car        No       Yes        No        No
# 1  I personally own or lease a car        No        No       Yes        No
# 2  I personally own or lease a car        No        No       Yes        No
# 3  I personally own or lease a car        No        No       Yes        No
# 4  I personally own or lease a car        No        No       Yes        No
#
#   qwelfare5 qsmartphone qshare1 qshare2 qshare3 qshare4 qshare5 qshare6  \
# 0        No         Yes     Yes      No      No      No      No      No
# 1        No         Yes      No      No      No      No      No     Yes
# 2        No         Yes      No      No      No      No      No     Yes
# 3        No          No      No      No      No      No      No     Yes
# 4        No          No      No      No      No      No      No     Yes
#
#   qshare7 qshare8 qtemphigh qtemplow qprecipitation qcitibike  \
# 0      No      No        79       58              0        No
# 1      No      No        66       51           0.25        No
# 2      No      No        66       51           0.25        No
# 3      No      No        73       57              0        No
# 4      No      No        73       57              0        No
#
#   qday1triptravelcode_sp qmodegrouping qsustainablemode        allwt  \
# 0              Citi Bike          Bike              Yes  2.269122796
# 1       Personal bicycle          Bike              Yes  0.868686684
# 2       Personal bicycle          Bike              Yes  0.868686684
# 3       Personal bicycle          Bike              Yes   2.43311884
# 4       Personal bicycle          Bike              Yes   2.43311884
#
#          qpurposerecode ntacode_home
# 0                School          NaN
# 1  Commute to/from work          NaN
# 2     Social/recreation          NaN
# 3     Social/recreation         QN60
# 4     Social/recreation         QN60

# %%
new_df = drop_cols_trip_diary_df[~drop_cols_trip_diary_df.qsurveyzone_home.str.contains('NOT CODED')]

# %%
new_df.to_csv('edited_trips_df.csv')

# %% [markdown]
# # Load-in CSV of semi-clean data

# %%
edited_trips_df = pd.read_csv('edited_trips_df.csv', index_col=0)

# %%
edited_trips_df.head()
# Out:
#     trip_id  uniqueid      qday  qday1typical qborough_home qsurveyzone_home  \
# 0   3101674    101674    Sunday           NaN        Queens    Middle Queens
# 1  11202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 2  12202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 3  51200330  50200330  Thursday  Very typical        Queens    Middle Queens
# 4  52200330  50200330  Thursday  Very typical        Queens    Middle Queens
#
#   qtripdaytime qborough_start qntacode_start surveyzone_start  \
# 0         NOON         Queens           QN43     Outer Queens
# 1           AM         Queens            NaN              NaN
# 2         NOON            NaN            NaN              NaN
# 3           AM         Queens            NaN    Middle Queens
# 4           AM         Queens            NaN    Middle Queens
#
#                  qday1tripend qborough_end qntacode_end surveyzone_end  \
# 0                        Home       Queens         QN76   Outer Queens
# 1                        Home          NaN          NaN            NaN
# 2  Park/Recreational area/Gym       Queens          NaN            NaN
# 3  Park/Recreational area/Gym       Queens          NaN  Middle Queens
# 4                        Home       Queens          NaN  Middle Queens
#
#              qday1tripendcode qday1triplength_cat number_of_trips_taken  \
# 0                        Home            11 to 15               3 trips
# 1                        Home            26 to 30               3 trips
# 2  Park/Recreational area/Gym            16 to 20               3 trips
# 3  Park/Recreational area/Gym            11 to 15               4 trips
# 4                        Home            11 to 15               4 trips
#
#   qgender            qincome qdisability1 qdisability2 qdisability3  \
# 0    Male  $50,000 - $74,999           No           No           No
# 1    Male  $50,000 - $74,999           No           No           No
# 2    Male  $50,000 - $74,999           No           No           No
# 3    Male  $50,000 - $74,999           No           No           No
# 4    Male  $50,000 - $74,999           No           No           No
#
#   qdisability4 qdisability5 qdisability6 qdisability7 qdisability8  \
# 0          Yes           No           No           No           No
# 1           No           No           No          Yes           No
# 2           No           No           No          Yes           No
# 3           No           No           No          Yes           No
# 4           No           No           No          Yes           No
#
#   qdisability9 qagecode            qracecode  \
# 0           No    25-34  White, Non-Hispanic
# 1           No    25-34  Black, Non-Hispanic
# 2           No    25-34  Black, Non-Hispanic
# 3           No    55-64  White, Non-Hispanic
# 4           No    55-64  White, Non-Hispanic
#
#                                        qeducation qlicense  \
# 0  High school graduate or equivalent (i.e., GED)      Yes
# 1            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 2            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 3  High school graduate or equivalent (i.e., GED)      Yes
# 4  High school graduate or equivalent (i.e., GED)      Yes
#
#                         qcaraccess qwelfare1 qwelfare2 qwelfare3 qwelfare4  \
# 0    I do not have access to a car        No       Yes        No        No
# 1  I personally own or lease a car        No        No       Yes        No
# 2  I personally own or lease a car        No        No       Yes        No
# 3  I personally own or lease a car        No        No       Yes        No
# 4  I personally own or lease a car        No        No       Yes        No
#
#   qwelfare5 qsmartphone qshare1 qshare2 qshare3 qshare4 qshare5 qshare6  \
# 0        No         Yes     Yes      No      No      No      No      No
# 1        No         Yes      No      No      No      No      No     Yes
# 2        No         Yes      No      No      No      No      No     Yes
# 3        No          No      No      No      No      No      No     Yes
# 4        No          No      No      No      No      No      No     Yes
#
#   qshare7 qshare8  qtemphigh  qtemplow  qprecipitation qcitibike  \
# 0      No      No       79.0      58.0            0.00        No
# 1      No      No       66.0      51.0            0.25        No
# 2      No      No       66.0      51.0            0.25        No
# 3      No      No       73.0      57.0            0.00        No
# 4      No      No       73.0      57.0            0.00        No
#
#   qday1triptravelcode_sp qmodegrouping qsustainablemode     allwt  \
# 0              Citi Bike          Bike              Yes  2.269123
# 1       Personal bicycle          Bike              Yes  0.868687
# 2       Personal bicycle          Bike              Yes  0.868687
# 3       Personal bicycle          Bike              Yes  2.433119
# 4       Personal bicycle          Bike              Yes  2.433119
#
#          qpurposerecode ntacode_home
# 0                School          NaN
# 1  Commute to/from work          NaN
# 2     Social/recreation          NaN
# 3     Social/recreation         QN60
# 4     Social/recreation         QN60

# %%
edited_trips_df['qborough_start'] = np.where(edited_trips_df['qborough_start'] == 2, edited_trips_df['qsurveyzone_home'], edited_trips_df['qborough_start'])
edited_trips_df['surveyzone_start'] = np.where(edited_trips_df['surveyzone_start'] == 2, edited_trips_df['qsurveyzone_home'], edited_trips_df['surveyzone_start'])
edited_trips_df['qborough_end'] = np.where(edited_trips_df['qborough_end'] == 2, edited_trips_df['qborough_home'], edited_trips_df['qborough_end'])
edited_trips_df['qsurveyzone_start'] = np.where(edited_trips_df['qsurveyzone_start'] == 2, edited_trips_df['surveyzone_start'], edited_trips_df['qsurveyzone_start'])
edited_trips_df['qsurveyzone_end'] = np.where(edited_trips_df['qsurveyzone_end'] == 2, edited_trips_df['qsurveyzone_home'], edited_trips_df['qsurveyzone_end'])
edited_trips_df['surveyzone_end'] = np.where(edited_trips_df['surveyzone_end'] == 2, edited_trips_df['qsurveyzone_home'], edited_trips_df['surveyzone_end'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'qsurveyzone_start'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-34a5917658ee> in <module>
#       2 edited_trips_df['surveyzone_start'] = np.where(edited_trips_df['surveyzone_start'] == 2, edited_trips_df['qsurveyzone_home'], edited_trips_df['surveyzone_start'])
#       3 edited_trips_df['qborough_end'] = np.where(edited_trips_df['qborough_end'] == 2, edited_trips_df['qborough_home'], edited_trips_df['qborough_end'])
# ----> 4 edited_trips_df['qsurveyzone_start'] = np.where(edited_trips_df['qsurveyzone_start'] == 2, edited_trips_df['surveyzone_start'], edited_trips_df['qsurveyzone_start'])
#       5 edited_trips_df['qsurveyzone_end'] = np.where(edited_trips_df['qsurveyzone_end'] == 2, edited_trips_df['qsurveyzone_home'], edited_trips_df['qsurveyzone_end'])
#       6 edited_trips_df['surveyzone_end'] = np.where(edited_trips_df['surveyzone_end'] == 2, edited_trips_df['qsurveyzone_home'], edited_trips_df['surveyzone_end'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'qsurveyzone_start'

# %%
edited_trips_df.qborough_start.value_counts()
# Out:
# Manhattan         1879
# Brooklyn          1620
# Queens            1390
# The Bronx         1069
# Staten Island      512
# Outside of NYC      84
# Don't know           8
# Refused              3
# Name: qborough_start, dtype: int64

# %%
edited_trips_df.qsurveyzone_start.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-a65a64825256> in <module>
# ----> 1 edited_trips_df.qsurveyzone_start.value_counts()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'qsurveyzone_start'

# %%
edited_trips_df['qsurveyzone_end'] = np.where(edited_trips_df['surveyzone_end'] == 'NA', edited_trips_df['qsurveyzone_start'], edited_trips_df['surveyzone_end'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'qsurveyzone_start'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-b86ef45c3e40> in <module>
# ----> 1 edited_trips_df['qsurveyzone_end'] = np.where(edited_trips_df['surveyzone_end'] == 'NA', edited_trips_df['qsurveyzone_start'], edited_trips_df['surveyzone_end'])
#       2
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'qsurveyzone_start'

# %%
edited_trips_df.qsurveyzone_end.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-841235ba3c2c> in <module>
# ----> 1 edited_trips_df.qsurveyzone_end.value_counts()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'qsurveyzone_end'

# %%
edited_trips_df.number_of_trips_taken. value_counts()
# Out:
# 2 trips     2098
# 3 trips     1734
# 4 trips     1634
# 5 trips      812
# 6 trips      576
# 1 trip       440
# 7 trips      238
# 8 trips      160
# 12 trips      72
# 9 trips       45
# 10 trips      40
# 11 trips      22
# 19 trips      20
# 15 trips      15
# Name: number_of_trips_taken, dtype: int64

# %%
edited_trips_df['number_of_trips_taken'] = edited_trips_df['number_of_trips_taken'].str.replace(r'\D', '')

# %%
print(edited_trips_df.dtypes)
# Out:
# trip_id                     int64
# uniqueid                    int64
# qday                       object
# qday1typical               object
# qborough_home              object
# qsurveyzone_home           object
# qtripdaytime               object
# qborough_start             object
# qntacode_start             object
# surveyzone_start           object
# qday1tripend               object
# qborough_end               object
# qntacode_end               object
# surveyzone_end             object
# qday1tripendcode           object
# qday1triplength_cat        object
# number_of_trips_taken      object
# qgender                    object
# qincome                    object
# qdisability1               object
# qdisability2               object
# qdisability3               object
# qdisability4               object
# qdisability5               object
# qdisability6               object
# qdisability7               object
# qdisability8               object
# qdisability9               object
# qagecode                   object
# qracecode                  object
# qeducation                 object
# qlicense                   object
# qcaraccess                 object
# qwelfare1                  object
# qwelfare2                  object
# qwelfare3                  object
# qwelfare4                  object
# qwelfare5                  object
# qsmartphone                object
# qshare1                    object
# qshare2                    object
# qshare3                    object
# qshare4                    object
# qshare5                    object
# qshare6                    object
# qshare7                    object
# qshare8                    object
# qtemphigh                 float64
# qtemplow                  float64
# qprecipitation            float64
# qcitibike                  object
# qday1triptravelcode_sp     object
# qmodegrouping              object
# qsustainablemode           object
# allwt                     float64
# qpurposerecode             object
# ntacode_home               object
# dtype: object

# %%
edited_trips_df['number_of_trips_taken'] = edited_trips_df['number_of_trips_taken'].astype('float64')

# %%
print(edited_trips_df.dtypes)
# Out:
# trip_id                     int64
# uniqueid                    int64
# qday                       object
# qday1typical               object
# qborough_home              object
# qsurveyzone_home           object
# qtripdaytime               object
# qborough_start             object
# qntacode_start             object
# surveyzone_start           object
# qday1tripend               object
# qborough_end               object
# qntacode_end               object
# surveyzone_end             object
# qday1tripendcode           object
# qday1triplength_cat        object
# number_of_trips_taken     float64
# qgender                    object
# qincome                    object
# qdisability1               object
# qdisability2               object
# qdisability3               object
# qdisability4               object
# qdisability5               object
# qdisability6               object
# qdisability7               object
# qdisability8               object
# qdisability9               object
# qagecode                   object
# qracecode                  object
# qeducation                 object
# qlicense                   object
# qcaraccess                 object
# qwelfare1                  object
# qwelfare2                  object
# qwelfare3                  object
# qwelfare4                  object
# qwelfare5                  object
# qsmartphone                object
# qshare1                    object
# qshare2                    object
# qshare3                    object
# qshare4                    object
# qshare5                    object
# qshare6                    object
# qshare7                    object
# qshare8                    object
# qtemphigh                 float64
# qtemplow                  float64
# qprecipitation            float64
# qcitibike                  object
# qday1triptravelcode_sp     object
# qmodegrouping              object
# qsustainablemode           object
# allwt                     float64
# qpurposerecode             object
# ntacode_home               object
# dtype: object

# %%
edited_trips_df.to_csv('edited_trips_df1.csv')

# %%
edited_trips_df = edited_trips_df.fillna(edited_trips_df['number_of_trips_taken'].value_counts().index[0])

# %%
edited_trips_df.number_of_trips_taken.value_counts()
# Out:
# 2.0     2106
# 3.0     1734
# 4.0     1634
# 5.0      812
# 6.0      576
# 1.0      440
# 7.0      238
# 8.0      160
# 12.0      72
# 9.0       45
# 10.0      40
# 11.0      22
# 19.0      20
# 15.0      15
# Name: number_of_trips_taken, dtype: int64

# %%
edited_trips_df.qtemphigh.value_counts()
# Out:
# 71.0    929
# 81.0    782
# 2.0     758
# 89.0    544
# 66.0    515
# 56.0    472
# 68.0    355
# 83.0    335
# 74.0    313
# 67.0    312
# 79.0    299
# 77.0    287
# 78.0    247
# 80.0    235
# 86.0    206
# 82.0    188
# 75.0    173
# 76.0    166
# 73.0    160
# 87.0    145
# 88.0    137
# 84.0    117
# 64.0    114
# 69.0     61
# 54.0     40
# 63.0     24
# Name: qtemphigh, dtype: int64

# %%
edited_trips_df['qpurposerecode']= edited_trips_df['qpurposerecode'].replace('NA', 'Commute to/from work')

# %%
edited_trips_df.to_csv('trips_with_NTA_df.csv')

# %%
edited_trips_df.isna().sum()
# Out:
# trip_id                   0
# uniqueid                  0
# qday                      0
# qday1typical              0
# qborough_home             0
# qsurveyzone_home          0
# qtripdaytime              0
# qborough_start            0
# qntacode_start            0
# surveyzone_start          0
# qday1tripend              0
# qborough_end              0
# qntacode_end              0
# surveyzone_end            0
# qday1tripendcode          0
# qday1triplength_cat       0
# number_of_trips_taken     0
# qgender                   0
# qincome                   0
# qdisability1              0
# qdisability2              0
# qdisability3              0
# qdisability4              0
# qdisability5              0
# qdisability6              0
# qdisability7              0
# qdisability8              0
# qdisability9              0
# qagecode                  0
# qracecode                 0
# qeducation                0
# qlicense                  0
# qcaraccess                0
# qwelfare1                 0
# qwelfare2                 0
# qwelfare3                 0
# qwelfare4                 0
# qwelfare5                 0
# qsmartphone               0
# qshare1                   0
# qshare2                   0
# qshare3                   0
# qshare4                   0
# qshare5                   0
# qshare6                   0
# qshare7                   0
# qshare8                   0
# qtemphigh                 0
# qtemplow                  0
# qprecipitation            0
# qcitibike                 0
# qday1triptravelcode_sp    0
# qmodegrouping             0
# qsustainablemode          0
# allwt                     0
# qpurposerecode            0
# ntacode_home              0
# dtype: int64

# %%
edited_trips_df = edited_trips_df.drop(columns=['disability'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-6def9c38bde7> in <module>
# ----> 1 edited_trips_df = edited_trips_df.drop(columns=['disability'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['disability'] not found in axis"

# %%
# check for NA's
NA_cols = [col for col in edited_trips_df.columns if 'NA' in col]
#print(list(edited_trips_df.columns))
print(NA_cols)
# Out:
# []

# %%
edited_trips_df.tail()
# Out:
#        trip_id  uniqueid       qday      qday1typical qborough_home  \
# 7972  62201178  50201178     Monday      Very typical        Queens
# 7973  62202898  50202898   Thursday      Very typical     The Bronx
# 7974  63200525  50200525  Wednesday  Somewhat typical        Queens
# 7975  64200525  50200525  Wednesday  Somewhat typical        Queens
# 7976  65200525  50200525  Wednesday  Somewhat typical        Queens
#
#      qsurveyzone_home qtripdaytime  qborough_start surveyzone_start  \
# 7972    Middle Queens           PM          Queens    Middle Queens
# 7973   Southern Bronx           PM  Outside of NYC                2
# 7974     Outer Queens           PM          Queens     Outer Queens
# 7975     Outer Queens           PM          Queens     Outer Queens
# 7976     Outer Queens           PM          Queens     Outer Queens
#
#                         qday1tripend qborough_end surveyzone_end  \
# 7972                            Home       Queens  Middle Queens
# 7973                            Home            2              2
# 7974  Friend or family member's home       Queens   Outer Queens
# 7975  Friend or family member's home       Queens   Outer Queens
# 7976                            Home       Queens   Outer Queens
#
#                     qday1tripendcode qday1triplength_cat  \
# 7972                            Home              0 to 5
# 7973                            Home            16 to 20
# 7974  Friend or family member's home            16 to 20
# 7975  Friend or family member's home             6 to 10
# 7976                            Home            11 to 15
#
#       number_of_trips_taken qgender            qincome qdisability1  \
# 7972                   12.0  Female  $75,000 - $99,999           No
# 7973                   12.0    Male  $150,000-$199,999           No
# 7974                   15.0  Female  $35,000 - $49,999           No
# 7975                   15.0  Female  $35,000 - $49,999           No
# 7976                   15.0  Female  $35,000 - $49,999           No
#
#      qdisability2 qdisability3 qdisability4 qdisability5 qdisability6  \
# 7972           No           No           No           No           No
# 7973           No           No           No           No           No
# 7974           No           No           No           No           No
# 7975           No           No           No           No           No
# 7976           No           No           No           No           No
#
#      qdisability7 qdisability8 qdisability9 qagecode            qracecode  \
# 7972          Yes           No           No    35-44  White, Non-Hispanic
# 7973          Yes           No           No    45-54             Hispanic
# 7974          Yes           No           No    25-34  Black, Non-Hispanic
# 7975          Yes           No           No    25-34  Black, Non-Hispanic
# 7976          Yes           No           No    25-34  Black, Non-Hispanic
#
#                                              qeducation qlicense  \
# 7972  Graduate degree (i.e., Master's, Professional,...      Yes
# 7973  Some college but degree not received or in pro...      Yes
# 7974  Some college but degree not received or in pro...      Yes
# 7975  Some college but degree not received or in pro...      Yes
# 7976  Some college but degree not received or in pro...      Yes
#
#                                              qcaraccess qwelfare1 qwelfare2  \
# 7972                    I personally own or lease a car        No        No
# 7973                    I personally own or lease a car        No        No
# 7974  I do not personally own or lease a car, but I ...        No        No
# 7975  I do not personally own or lease a car, but I ...        No        No
# 7976  I do not personally own or lease a car, but I ...        No        No
#
#      qwelfare3 qwelfare4 qwelfare5 qsmartphone qshare1 qshare2 qshare3  \
# 7972       Yes        No        No         Yes      No      No      No
# 7973       Yes        No        No         Yes      No      No      No
# 7974       Yes        No        No         Yes      No      No      No
# 7975       Yes        No        No         Yes      No      No      No
# 7976       Yes        No        No         Yes      No      No      No
#
#      qshare4 qshare5 qshare6 qshare7 qshare8  qtemphigh  qtemplow  \
# 7972      No      No     Yes      No      No       68.0      55.0
# 7973      No      No     Yes      No      No       82.0      60.0
# 7974      No      No     Yes      No      No       71.0      56.0
# 7975      No      No     Yes      No      No       71.0      56.0
# 7976      No      No     Yes      No      No       71.0      56.0
#
#       qprecipitation qcitibike qday1triptravelcode_sp qmodegrouping  \
# 7972            0.29        No                   Walk          Walk
# 7973            0.00        No           Personal car           Car
# 7974            0.22        No           Personal car           Car
# 7975            0.22        No           Personal car           Car
# 7976            0.22        No           Personal car           Car
#
#      qsustainablemode     allwt        qpurposerecode
# 7972              Yes  0.610785              Shopping
# 7973               No  0.297777  Commute to/from work
# 7974               No  0.821767     Social/recreation
# 7975               No  0.821767     Social/recreation
# 7976               No  0.821767  Commute to/from work

# %%
edited_trips_df['qborough_start'] = np.where(edited_trips_df['qborough_start'] == 2, edited_trips_df['qsurveyzone_home'], edited_trips_df['qborough_start'])
edited_trips_df['surveyzone_start'] = np.where(edited_trips_df['surveyzone_start'] == 2, edited_trips_df['qsurveyzone_home'], edited_trips_df['surveyzone_start'])
edited_trips_df['qborough_end'] = np.where(edited_trips_df['qborough_end'] == 2, edited_trips_df['qborough_home'], edited_trips_df['qborough_end'])
#edited_trips_df['qsurveyzone_start'] = np.where(edited_trips_df['qsurveyzone_start'] == 2, edited_trips_df['surveyzone_start'], edited_trips_df['qsurveyzone_start'])
#edited_trips_df['qsurveyzone_end'] = np.where(edited_trips_df['qsurveyzone_end'] == 2, edited_trips_df['qsurveyzone_home'], edited_trips_df['qsurveyzone_end'])
edited_trips_df['surveyzone_end'] = np.where(edited_trips_df['surveyzone_end'] == 2, edited_trips_df['qsurveyzone_home'], edited_trips_df['surveyzone_end'])

# %%
#drop NTA columns
edited_trips_df = edited_trips_df.drop(columns=['qntacode_start', 'qntacode_end', 'ntacode_home'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-64f236add523> in <module>
#       1 #drop NTA columns
# ----> 2 edited_trips_df = edited_trips_df.drop(columns=['qntacode_start', 'qntacode_end', 'ntacode_home'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3944                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3945             else:
# -> 3946                 new_axis = axis.drop(labels, errors=errors)
#    3947             result = self.reindex(**{axis_name: new_axis})
#    3948
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5338         if mask.any():
#    5339             if errors != "ignore":
# -> 5340                 raise KeyError("{} not found in axis".format(labels[mask]))
#    5341             indexer = indexer[~mask]
#    5342         return self.delete(indexer)
#
# KeyError: "['qntacode_start' 'qntacode_end' 'ntacode_home'] not found in axis"

# %%
edited_trips_df.head()
# Out:
#     trip_id  uniqueid      qday  qday1typical qborough_home qsurveyzone_home  \
# 0   3101674    101674    Sunday             2        Queens    Middle Queens
# 1  11202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 2  12202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 3  51200330  50200330  Thursday  Very typical        Queens    Middle Queens
# 4  52200330  50200330  Thursday  Very typical        Queens    Middle Queens
#
#   qtripdaytime qborough_start surveyzone_start                qday1tripend  \
# 0         NOON         Queens     Outer Queens                        Home
# 1           AM         Queens    Middle Queens                        Home
# 2         NOON  Middle Queens    Middle Queens  Park/Recreational area/Gym
# 3           AM         Queens    Middle Queens  Park/Recreational area/Gym
# 4           AM         Queens    Middle Queens                        Home
#
#   qborough_end surveyzone_end            qday1tripendcode qday1triplength_cat  \
# 0       Queens   Outer Queens                        Home            11 to 15
# 1       Queens  Middle Queens                        Home            26 to 30
# 2       Queens  Middle Queens  Park/Recreational area/Gym            16 to 20
# 3       Queens  Middle Queens  Park/Recreational area/Gym            11 to 15
# 4       Queens  Middle Queens                        Home            11 to 15
#
#    number_of_trips_taken qgender            qincome qdisability1 qdisability2  \
# 0                    3.0    Male  $50,000 - $74,999           No           No
# 1                    3.0    Male  $50,000 - $74,999           No           No
# 2                    3.0    Male  $50,000 - $74,999           No           No
# 3                    4.0    Male  $50,000 - $74,999           No           No
# 4                    4.0    Male  $50,000 - $74,999           No           No
#
#   qdisability3 qdisability4 qdisability5 qdisability6 qdisability7  \
# 0           No          Yes           No           No           No
# 1           No           No           No           No          Yes
# 2           No           No           No           No          Yes
# 3           No           No           No           No          Yes
# 4           No           No           No           No          Yes
#
#   qdisability8 qdisability9 qagecode            qracecode  \
# 0           No           No    25-34  White, Non-Hispanic
# 1           No           No    25-34  Black, Non-Hispanic
# 2           No           No    25-34  Black, Non-Hispanic
# 3           No           No    55-64  White, Non-Hispanic
# 4           No           No    55-64  White, Non-Hispanic
#
#                                        qeducation qlicense  \
# 0  High school graduate or equivalent (i.e., GED)      Yes
# 1            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 2            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 3  High school graduate or equivalent (i.e., GED)      Yes
# 4  High school graduate or equivalent (i.e., GED)      Yes
#
#                         qcaraccess qwelfare1 qwelfare2 qwelfare3 qwelfare4  \
# 0    I do not have access to a car        No       Yes        No        No
# 1  I personally own or lease a car        No        No       Yes        No
# 2  I personally own or lease a car        No        No       Yes        No
# 3  I personally own or lease a car        No        No       Yes        No
# 4  I personally own or lease a car        No        No       Yes        No
#
#   qwelfare5 qsmartphone qshare1 qshare2 qshare3 qshare4 qshare5 qshare6  \
# 0        No         Yes     Yes      No      No      No      No      No
# 1        No         Yes      No      No      No      No      No     Yes
# 2        No         Yes      No      No      No      No      No     Yes
# 3        No          No      No      No      No      No      No     Yes
# 4        No          No      No      No      No      No      No     Yes
#
#   qshare7 qshare8  qtemphigh  qtemplow  qprecipitation qcitibike  \
# 0      No      No       79.0      58.0            0.00        No
# 1      No      No       66.0      51.0            0.25        No
# 2      No      No       66.0      51.0            0.25        No
# 3      No      No       73.0      57.0            0.00        No
# 4      No      No       73.0      57.0            0.00        No
#
#   qday1triptravelcode_sp qmodegrouping qsustainablemode     allwt  \
# 0              Citi Bike          Bike              Yes  2.269123
# 1       Personal bicycle          Bike              Yes  0.868687
# 2       Personal bicycle          Bike              Yes  0.868687
# 3       Personal bicycle          Bike              Yes  2.433119
# 4       Personal bicycle          Bike              Yes  2.433119
#
#          qpurposerecode
# 0                School
# 1  Commute to/from work
# 2     Social/recreation
# 3     Social/recreation
# 4     Social/recreation

# %%
edited_trips_df['qday1typical']= edited_trips_df['qday1typical'].replace(2 , 'Very typical')
edited_trips_df['qeducation']= edited_trips_df['qeducation'].replace(2 , "Bachelor's degree (i.e., BA, BS, AB)")

# %%
edited_trips_df.head()
# Out:
#     trip_id  uniqueid      qday  qday1typical qborough_home qsurveyzone_home  \
# 0   3101674    101674    Sunday  Very typical        Queens    Middle Queens
# 1  11202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 2  12202717  10202717  Saturday  Very typical        Queens    Middle Queens
# 3  51200330  50200330  Thursday  Very typical        Queens    Middle Queens
# 4  52200330  50200330  Thursday  Very typical        Queens    Middle Queens
#
#   qtripdaytime qborough_start surveyzone_start                qday1tripend  \
# 0         NOON         Queens     Outer Queens                        Home
# 1           AM         Queens    Middle Queens                        Home
# 2         NOON  Middle Queens    Middle Queens  Park/Recreational area/Gym
# 3           AM         Queens    Middle Queens  Park/Recreational area/Gym
# 4           AM         Queens    Middle Queens                        Home
#
#   qborough_end surveyzone_end            qday1tripendcode qday1triplength_cat  \
# 0       Queens   Outer Queens                        Home            11 to 15
# 1       Queens  Middle Queens                        Home            26 to 30
# 2       Queens  Middle Queens  Park/Recreational area/Gym            16 to 20
# 3       Queens  Middle Queens  Park/Recreational area/Gym            11 to 15
# 4       Queens  Middle Queens                        Home            11 to 15
#
#    number_of_trips_taken qgender            qincome qdisability1 qdisability2  \
# 0                    3.0    Male  $50,000 - $74,999           No           No
# 1                    3.0    Male  $50,000 - $74,999           No           No
# 2                    3.0    Male  $50,000 - $74,999           No           No
# 3                    4.0    Male  $50,000 - $74,999           No           No
# 4                    4.0    Male  $50,000 - $74,999           No           No
#
#   qdisability3 qdisability4 qdisability5 qdisability6 qdisability7  \
# 0           No          Yes           No           No           No
# 1           No           No           No           No          Yes
# 2           No           No           No           No          Yes
# 3           No           No           No           No          Yes
# 4           No           No           No           No          Yes
#
#   qdisability8 qdisability9 qagecode            qracecode  \
# 0           No           No    25-34  White, Non-Hispanic
# 1           No           No    25-34  Black, Non-Hispanic
# 2           No           No    25-34  Black, Non-Hispanic
# 3           No           No    55-64  White, Non-Hispanic
# 4           No           No    55-64  White, Non-Hispanic
#
#                                        qeducation qlicense  \
# 0  High school graduate or equivalent (i.e., GED)      Yes
# 1            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 2            Bachelor's degree (i.e., BA, BS, AB)      Yes
# 3  High school graduate or equivalent (i.e., GED)      Yes
# 4  High school graduate or equivalent (i.e., GED)      Yes
#
#                         qcaraccess qwelfare1 qwelfare2 qwelfare3 qwelfare4  \
# 0    I do not have access to a car        No       Yes        No        No
# 1  I personally own or lease a car        No        No       Yes        No
# 2  I personally own or lease a car        No        No       Yes        No
# 3  I personally own or lease a car        No        No       Yes        No
# 4  I personally own or lease a car        No        No       Yes        No
#
#   qwelfare5 qsmartphone qshare1 qshare2 qshare3 qshare4 qshare5 qshare6  \
# 0        No         Yes     Yes      No      No      No      No      No
# 1        No         Yes      No      No      No      No      No     Yes
# 2        No         Yes      No      No      No      No      No     Yes
# 3        No          No      No      No      No      No      No     Yes
# 4        No          No      No      No      No      No      No     Yes
#
#   qshare7 qshare8  qtemphigh  qtemplow  qprecipitation qcitibike  \
# 0      No      No       79.0      58.0            0.00        No
# 1      No      No       66.0      51.0            0.25        No
# 2      No      No       66.0      51.0            0.25        No
# 3      No      No       73.0      57.0            0.00        No
# 4      No      No       73.0      57.0            0.00        No
#
#   qday1triptravelcode_sp qmodegrouping qsustainablemode     allwt  \
# 0              Citi Bike          Bike              Yes  2.269123
# 1       Personal bicycle          Bike              Yes  0.868687
# 2       Personal bicycle          Bike              Yes  0.868687
# 3       Personal bicycle          Bike              Yes  2.433119
# 4       Personal bicycle          Bike              Yes  2.433119
#
#          qpurposerecode
# 0                School
# 1  Commute to/from work
# 2     Social/recreation
# 3     Social/recreation
# 4     Social/recreation

# %%
#calculate median temperature

# %%
clean_trip_df = edited_trips_df.to_csv('clean_trip_df.csv')

# %% [markdown]
# # Attempt to recat disability cols

# %%
#edited_trips_df['disability'] = ['Yes' if x >= 1 else 'No' for x in np.sum(edited_trips_df.filter(like='disability').values == 'Yes',1)]

# %%
edited_trips_df = edited_trips_df.drop(columns=['disablity'])

# %%
#edited_trips_df["disability"] = (edited_trips_df[(edited_trips_df.filter(like= 'disability'=='Yes').sum(axis=1)==1]==8)

# %%
# def loc(df):
#     df = edited_trips_df(disability = 'Yes')
#     df.loc[df['qdisability1'] == 'Yes', 'disability'] == 'Yes'
#     df.loc[df['qdisability2'] == 'Yes', 'disability'] == 'Yes'
#     df.loc[df['qdisability3'] == 'Yes', 'disability'] == 'Yes'
#     df.loc[df['qdisability4'] == 'Yes', 'disability'] == 'Yes'
#     df.loc[df['qdisability5'] == 'Yes', 'disability'] == 'Yes'
#     df.loc[df['qdisability6'] == 'Yes', 'disability'] == 'Yes'
#     df.loc[df['qdisability7'] == 'Yes', 'disability'] == 'Yes'
#     df.loc[df['qdisability8'] == 'Yes', 'disability'] == 'Yes'
#     df.loc[df['qdisability9'] == 'Yes', 'disability'] == 'Yes'
#     return df

# %%
# edited_trips_df['disability'] = 'No'
# edited_trips_df.loc[edited_trips_df['qdisability1'] == 'Yes', 'disablity'] = 'Yes'
# edited_trips_df.loc[edited_trips_df['qdisability2'] == 'Yes', 'disablity'] = 'Yes'
# edited_trips_df.loc[edited_trips_df['qdisability3'] == 'Yes', 'disablity'] = 'Yes'
# edited_trips_df.loc[edited_trips_df['qdisability4'] == 'Yes', 'disablity'] = 'Yes'
# edited_trips_df.loc[edited_trips_df['qdisability5'] == 'Yes', 'disablity'] = 'Yes'
# edited_trips_df.loc[edited_trips_df['qdisability6'] == 'Yes', 'disablity'] = 'Yes'
# edited_trips_df.loc[edited_trips_df['qdisability7'] == 'Yes', 'disablity'] = 'Yes'
# edited_trips_df.loc[edited_trips_df['qdisability8'] == 'Yes', 'disablity'] = 'Yes'
# edited_trips_df.loc[edited_trips_df['qdisability9'] == 'Yes', 'disablity'] = 'Yes'

# %%
disability = edited_trips_df.filter(like= 'disability', axis=1)
disability.head()

# %%
# def applyFunc(disability):
#     if disability == 'Yes':
#         return "Yes"
#     elif disability == 'No':
#         return 'No'
#     return ''

# %%
# https://stackoverflow.com/questions/43905930/conditional-if-statement-if-value-in-row-contains-string-set-another-column
# disability['disability'] = pd.np.where(disability.qdisability1.str.contains("Yes"), "Yes",
#                    pd.np.where(disability.qdisability2.str.contains("Yes"), "Yes",
#                 pd.np.where(disability.qdisability3.str.contains("Yes"), "Yes",
#                 pd.np.where(disability.qdisability4.str.contains("Yes"), "Yes",
#                 pd.np.where(disability.qdisability5.str.contains("Yes"), "Yes",
#                 pd.np.where(disability.qdisability6.str.contains("Yes"), "Yes",
#                 pd.np.where(disability.qdisability7.str.contains("Yes"), "Yes",
#                 pd.np.where(disability.qdisability8.str.contains("Yes"), "Yes",
#                 pd.np.where(disability.qdisability9.str.contains("Yes"), "Yes")))

# %%
disability = disability.drop(columns=['disability'])

# %% [markdown]
# # EDA: Main Survey

# %%
main_survey_df.shape

# %%
main_survey_df.info()

# %%
main_survey_df.isna().sum()
